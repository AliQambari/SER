# %%
import librosa
import numpy as np
import librosa.display
import matplotlib.pyplot as plt
import os
dir_list = os.listdir('D:/AAA_video_course/Programming/A_main/zzzdatasets/TESS')
dir_list.sort()
dir_list
# Out:
# ['OAF_Fear',
#  'OAF_Pleasant_surprise',
#  'OAF_Sad',
#  'OAF_angry',
#  'OAF_disgust',
#  'OAF_happy',
#  'OAF_neutral',
#  'YAF_angry',
#  'YAF_disgust',
#  'YAF_fear',
#  'YAF_happy',
#  'YAF_neutral',
#  'YAF_pleasant_surprised',
#  'YAF_sad']

# %%
dir_fear = "D:/thesis_codes/9_Spectrogram_2DCNN/specs/fear/"   
dir_sad = "D:/thesis_codes/9_Spectrogram_2DCNN/specs/sad/"    
dir_ps = "D:/thesis_codes/9_Spectrogram_2DCNN/specs/pleasnat surprised"
dir_neutral= "D:/thesis_codes/9_Spectrogram_2DCNN/specs/neutral/"    
dir_angry= "D:/thesis_codes/9_Spectrogram_2DCNN/specs/angry/"         
dir_happy = "D:/thesis_codes/9_Spectrogram_2DCNN/specs/happy/"    
dir_disgust = "D:/thesis_codes/9_Spectrogram_2DCNN/specs/disgust/"

# %%
"""i = "D:/AAA_video_course/Programming/dataset/Actor_01/03-01-01-01-01-01-01.wav"
file_name=os.path.basename(i)
part = file_name.split('.')[0]
part = file_name.split("-")  
part
"""
# Out:
# 'i = "D:/AAA_video_course/Programming/dataset/Actor_01/03-01-01-01-01-01-01.wav"\nfile_name=os.path.basename(i)\npart = file_name.split(\'.\')[0]\npart = file_name.split("-")  \npart\n'

# %%
i = "D:/AAA_video_course/Programming/dataset/Actor_01/03-01-01-01-01-01-01.wav"
x, sr = librosa.load(i, sr=48000)
mel_spect = librosa.feature.melspectrogram(x, sr=sr)
mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
librosa.display.specshow(mel_spect, y_axis='mel', x_axis='time');
plt.axis('off')
plt.margins(x=0)
plt.savefig(dir_sad+os.path.basename(i)+'.jpg',dpi = 120,bbox_inches='tight', pad_inches = 0)
# Out:
# <ipython-input-4-faad244e01fd>:3: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr)

# %%
import noisereduce as nr
from scipy.io import wavfile
i = "D:/AAA_video_course/Programming/dataset/Actor_01/03-01-01-01-01-01-01.wav"
x, sr = librosa.load(i, sr=48000)
#x= nr.reduce_noise(y=x, sr=sr)
#avfile.write("mywav_reduced_noise.wav", sr, yt)
yt, index = librosa.effects.trim(x, top_db=60)
mel_spect = librosa.feature.melspectrogram(yt, sr=sr)
mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
librosa.display.specshow(mel_spect, y_axis='mel', x_axis='time');
#plt.gcf().set_size_inches(3, 3)
plt.axis('off')
plt.margins(x=0)
plt.savefig(dir_sad+os.path.basename(i)+'.jpg',dpi = 200,bbox_inches='tight', pad_inches = 0)
# Out:
# <ipython-input-5-dc68c01b683f>:8: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(yt, sr=sr)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display

plt.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display

plt.figure(figsize=(14, 5))
librosa.display.waveshow(yt, sr=sr)

# %%
def create_spectrogram(data, sr):
    # stft function converts the data into short term fourier transform
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.axis('off')
    plt.margins(x=0)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')   

    #librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
    #plt.colorbar()

# %%
i = "D:/AAA_video_course/Programming/dataset/Actor_01/03-01-01-01-01-01-01.wav"
import noisereduce as nr
x, sr = librosa.load(i, sr=48000)
x = nr.reduce_noise(y=x, sr=sr)
x, index = librosa.effects.trim(x, top_db=60) 
create_spectrogram(x, sr)

# %%
#check
import noisereduce as nr

vv = "D:/AAA_video_course/Programming/dataset/Actor_01/03-01-01-01-01-01-01.wav"
k, sr = librosa.load(vv, sr = 48000)      
mel_spect = librosa.feature.melspectrogram(k, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
#mel_spect = librosa.power_to_db(mel_spect,ref=np.max)
librosa.display.specshow(mel_spect, y_axis='mel', x_axis='time');
#plt.axis('off')
sr
# Out:
# <ipython-input-85-b587dd365d22>:6: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(k, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# 48000

# %%
from scipy.io.wavfile import read as read_wav
sampling_rate, data=read_wav(i) # enter your filename
print (sampling_rate)
# Out:
# 48000
# <ipython-input-68-f3ff72a32c52>:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampling_rate, data=read_wav(i) # enter your filename
# <ipython-input-68-f3ff72a32c52>:2: WavFileWarning: Incomplete chunk ID: b'\x00', ignoring it.
#   sampling_rate, data=read_wav(i) # enter your filename

# %%
# اجرا نشود

# %%
#TESS
import glob
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
for i in glob.glob("D:/AAA_video_course/Programming/A_main/zzzdatasets/TESS/*/*.wav"):
        #کاهش نویز و حذف صدای خالی - کتابخانه ها برای توضیح روش بررسی شود 

        
        x, sr = librosa.load(i, sr=48000)       
        mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
        mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
        librosa.display.specshow(mel_spect, y_axis='mel', x_axis='time');
        plt.axis('off')
        plt.margins(x=0)
        
        file_name=os.path.basename(i)
        part=file_name.split('_')
        
        if part[2]=='angry.wav':
            plt.savefig(dir_angry+os.path.basename(i)+'.jpg',dpi = 120,bbox_inches='tight', pad_inches = 0)
            plt.close()
        elif part[2] == 'disgust.wav':
            plt.savefig(dir_disgust+os.path.basename(i)+'.jpg',dpi = 120,bbox_inches='tight', pad_inches = 0)
            plt.close()
        elif part[2] == 'fear.wav':
            plt.savefig(dir_fear+os.path.basename(i)+'.jpg',dpi = 120,bbox_inches='tight', pad_inches = 0)
            plt.close()
            
        if part[2] == 'happy.wav':   #elif
            plt.savefig(dir_happy+os.path.basename(i)+'.jpg',dpi = 120,bbox_inches='tight', pad_inches = 0)
            plt.close()
        elif part[2] == 'neutral.wav':
            plt.savefig(dir_neutral+os.path.basename(i)+'.jpg',dpi = 120,bbox_inches='tight', pad_inches = 0)
            plt.close()
            
        elif part[2] == 'ps.wav':
            plt.savefig(dir_ps+os.path.basename(i)+'.jpg',dpi = 120,bbox_inches='tight', pad_inches = 0)
            plt.close()
        elif part[2] == 'sad.wav':
            plt.savefig(dir_sad+os.path.basename(i)+'.jpg',dpi = 120,bbox_inches='tight', pad_inches = 0)
            plt.close()
# Out:
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[-3.0306887e-06 -8.6179869e-05 -1.8366406e-04 ...  8.4069601e-05
#   8.0743674e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[ 2.3271830e-06 -5.2223539e-05 -9.5771975e-05 ...  1.1807728e-04
#   5.4677203e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[-3.3100055e-06  4.1739117e-06  3.5109475e-05 ... -1.1084293e-03
#  -7.1237766e-04  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[ 8.9940568e-06 -5.6834033e-05 -1.6548763e-04 ... -1.1849800e-04
#  -1.0466553e-04  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[-1.0474705e-05 -3.5225326e-05 -1.8519757e-05 ...  9.9165761e-04
#   6.7110296e-04  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[-1.6022075e-06 -6.3024294e-05 -1.2199559e-04 ...  2.0874028e-04
#   1.6244627e-04  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[ 4.5735351e-06 -1.6336107e-07  2.6651873e-05 ...  3.6237662e-04
#   2.4698160e-04  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[ 2.8754409e-06 -4.1401589e-05 -9.6644937e-05 ...  2.0918238e-03
#   1.2608056e-03  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[-1.0988212e-05 -1.2924928e-04 -2.0315275e-04 ...  1.8403179e-04
#   9.9733479e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[ 3.3746801e-05  3.1431329e-05 -1.0422680e-04 ...  9.1256778e-05
#   4.6306413e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[ 3.5896951e-06 -4.3108565e-05 -1.6152831e-04 ... -1.6329075e-04
#  -1.7015263e-04  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[-5.9528929e-06 -4.2042324e-05 -1.5022441e-04 ...  4.5991759e-04
#   2.2571128e-04  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[-1
0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[0.00044359 0.00041195 0.0002199  ... 0.00038787 0.00015343 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[ 3.4441185e-04  5.5835576e-04  6.3063070e-04 ... -8.0268845e-05
#   6.3788975e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[ 3.2563454e-05 -9.3059287e-05 -2.2002263e-04 ...  6.3069376e-05
#   7.9885242e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[ 2.6999410e-07 -2.6316766e-04 -3.9639079e-04 ... -5.1131472e-05
#   4.0536946e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[ 1.4956366e-05 -6.3360370e-05 -2.6663873e-04 ...  5.9958093e-04
#   2.7996846e-04  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[ 1.0916541e-04  1.5513488e-04  4.5345692e-04 ... -9.4545852e-05
#   9.9426259e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[1.67473190e-04 2.84522219e-04 3.82258324e-04 ... 1.04244056e-04
#  1.46548846e-05 0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[-4.8530630e-05 -1.9795680e-05  1.8088931e-04 ...  1.2278660e-04
#   1.2696307e-04  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')
# <ipython-input-92-0d2dc2c70b3e>:12: FutureWarning: Pass y=[1.9734906e-04 1.3622404e-04 1.4885294e-05 ... 1.8102601e-04 4.8688729e-05
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=512, hop_length=512,win_length=512, window='hann')

# %%
#RAVDESS

"""import glob
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
for i in glob.glob("D:/AAA_video_course/Programming/dataset/*/*.wav"):
        #کاهش نویز و حذف صدای خالی - کتابخانه ها برای توضیح روش بررسی شود 
        x, sr = librosa.load(i, sr=48000)
        
       
        #x = nr.reduce_noise(y=x, sr=sr)
        x, index = librosa.effects.trim(x, top_db=60)    
        X = librosa.stft(x)
        Xdb = librosa.amplitude_to_db(abs(X))
        plt.axis('off')
        plt.margins(x=0)
        librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')      
     
        
        
        """
        mel_spect = librosa.feature.melspectrogram(x, sr=sr, n_fft=1024, hop_length=100)
        mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
        librosa.display.specshow(mel_spect, y_axis='mel', fmax=20000, x_axis='time');
        plt.axis('off')
        plt.margins(x=0)
          """
        file_name=os.path.basename(i)
        part = file_name.split('.')[0]
        part = file_name.split("-")
        if part[2] == '01':
            plt.savefig(dir_neutral+os.path.basename(i)+'.jpg',dpi = 120,bbox_inches='tight', pad_inches = 0)
            plt.close()
        elif part[2] == '02':
            plt.savefig(dir_calm+os.path.basename(i)+'.jpg',dpi = 120,bbox_inches='tight', pad_inches = 0)
            plt.close()
        elif part[2] == '03':
            plt.savefig(dir_happy+os.path.basename(i)+'.jpg',dpi = 120,bbox_inches='tight', pad_inches = 0)
            plt.close()
        elif part[2] == '04':
            plt.savefig(dir_sad+os.path.basename(i)+'.jpg',dpi = 120,bbox_inches='tight', pad_inches = 0)
            plt.close()
        elif part[2] == '05':
            plt.savefig(dir_angry+os.path.basename(i)+'.jpg',dpi = 120,bbox_inches='tight', pad_inches = 0)
            plt.close()
        elif part[2] == '06':
            plt.savefig(dir_fear+os.path.basename(i)+'.jpg',dpi = 120,bbox_inches='tight', pad_inches = 0)
            plt.close()
        elif part[2] == '07':
            plt.savefig(dir_disgust+os.path.basename(i)+'.jpg',dpi = 120,bbox_inches='tight', pad_inches = 0)
            plt.close()
        elif part[2] == '08':
            plt.savefig(dir_surprise+os.path.basename(i)+'.jpg',dpi = 120,bbox_inches='tight', pad_inches = 0)
            plt.close()
"""

# %%
plt.close("all")

# %%
import splitfolders

input_folder = "D:/thesis_codes/9_Spectrogram_2DCNN/specs"

# %%
splitfolders.ratio(input_folder, output="output",
    seed=1337, ratio=(.8, .2), group_prefix=None, move=False)
# Out:
# Copying files: 2800 files [00:14, 189.60 files/s]

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix, classification_report
from tqdm import tqdm

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import warnings
warnings.filterwarnings('ignore')

# %%
train_dir = 'D:/thesis_codes/9_Spectrogram_2DCNN/output/train'
validation_dir = 'D:/thesis_codes/9_Spectrogram_2DCNN/output/val'

# %%
"""emotions={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}
observed_emotions=['calm', 'happy', 'fearful', 'disgust','neutral','surprised','sad','angry']
len(observed_emotions)
"""
# Out:
# "emotions={\n  '01':'neutral',\n  '02':'calm',\n  '03':'happy',\n  '04':'sad',\n  '05':'angry',\n  '06':'fearful',\n  '07':'disgust',\n  '08':'surprised'\n}\nobserved_emotions=['calm', 'happy', 'fearful', 'disgust','neutral','surprised','sad','angry']\nlen(observed_emotions)\n"

# %%
name_example = "speech_03-01-05-02-02-01-11"
nn = name_example[10:12]
nn
# Out:
# '01'

# %%
import glob

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sn

import cv2
from random import randint

import numpy as np

# %%
CLASSES, emotions = [], [] # names of classes, count of images for each class

for root, dirs, files in os.walk('D:/thesis_codes/9_Spectrogram_2DCNN/output'):
    f = os.path.basename(root)    # get class name - Amethyst, Onyx, etc    
        
    if len(files) > 0:
        emotions.append(len(files))
        if f not in CLASSES:
            CLASSES.append(f) # add folder name
    
    # uncomment this block if you want a text output about each subfolder
    #count_dirs = 0
    #for f in dirs:           # count subfolders
        #count_dirs += 1
    #depth = root.split(os.sep)
    #print((len(depth) - 2) * '--'+'>', '{}:\t {} folders, {} imgs'.format(os.path.basename(root), count_dirs, gems[-1] if gems!=[] else 0)) 
    
classes_count = len(CLASSES) # 8 = number of classes
print('{} classes with {} images in total'.format(len(CLASSES), sum(emotions)))

f, ax = plt.subplots(figsize=(15,6))
if(emotions[0])<10:
    plt.bar(range(classes_count), emotions[classes_count:], label = 'Train data')
    plt.bar(range(classes_count), emotions[0:classes_count], label = 'Test data')
else:
    plt.bar(range(classes_count), emotions[0:classes_count], label = 'Train data')
    plt.bar(range(classes_count), emotions[classes_count:], label = 'Test data')
ax.grid()
ax.legend(fontsize = 12);
# Out:
# 7 classes with 2800 images in total

# %%
img_w, img_h = 220, 220

# %%
CLASSES
classlist = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'ps', 'sad']
classlist
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'ps', 'sad']

# %%
def read_imgs_lbls(_dir):
    Images, Labels = [], []
    for root, dirs, files in os.walk(_dir):
        f = os.path.basename(root)  # get class name - Amethyst, Onyx, etc       
        for file in files:
            Labels.append(f)
            try:
                image = cv2.imread(root+'/'+file)              # read the image (OpenCV)
                image = cv2.resize(image,(int(128), int(128)))       # resize the image (images are different sizes)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # converts an image from BGR color space to RGB
                Images.append(image)
            except Exception as e:
                print(e)
    Images = np.array(Images)
    return (Images, Labels)

# %%
def get_class_index(Labels):
    for i, n in enumerate(Labels):
        for j, k in enumerate(CLASSES):    # foreach CLASSES
            if n == k:
                Labels[i] = j
    Labels = np.array(Labels)
    return Labels

# %%
Train_Imgs, Train_Lbls = read_imgs_lbls(train_dir)
Train_Lbls = get_class_index(Train_Lbls)
print('Shape of train images: {}'.format(Train_Imgs.shape))
print('Shape of train labels: {}'.format(Train_Lbls.shape))
# Out:
# Shape of train images: (2240, 128, 128, 3)
# Shape of train labels: (2240,)

# %%
dim = 4#you can change it;  4x4 dimension flat plot

f,ax = plt.subplots(dim,dim) 
f.subplots_adjust(0,0,2,2)
for i in range(0,dim):
    for j in range(0,dim):
        rnd_number = randint(0,len(Train_Imgs))
        cl = Train_Lbls[rnd_number]
        ax[i,j].imshow(Train_Imgs[rnd_number])
        ax[i,j].set_title(CLASSES[cl]+': ' + str(cl))
        ax[i,j].axis('off')

# %%
#اضافه دفعه دوم

# %%
"""y_val=keras.utils.to_categorical(y_val, num_classes=8, dtype='float32')
y_train =keras.utils.to_categorical(y_train, num_classes=8, dtype='float32')
y_train
"""
# Out:
# "y_val=keras.utils.to_categorical(y_val, num_classes=8, dtype='float32')\ny_train =keras.utils.to_categorical(y_train, num_classes=8, dtype='float32')\ny_train\n"

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(Train_Imgs, Train_Lbls, shuffle = True, test_size = 0.2, random_state = 42)
print('Shape of X_train: {}, y_train: {} '.format(X_train.shape, y_train.shape))
print('Shape of X_val: {}, y_val: {} '.format(X_val.shape, y_val.shape))
# Out:
# Shape of X_train: (1792, 128, 128, 3), y_train: (1792,)
# Shape of X_val: (448, 128, 128, 3), y_val: (448,)

# %%
# اضافه های جدید

# %%
"""X_train = X_train.astype('float32')
X_val = X_val.astype('float32')
X_train /= 255
X_val /= 255
"""
# Out:
# "X_train = X_train.astype('float32')\nX_val = X_val.astype('float32')\nX_train /= 255\nX_val /= 255\n"

# %%
from tensorflow.python.client import device_lib
devices = device_lib.list_local_devices()
print(devices)
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12922798447583639721
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 2924648859
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 540805463900516004
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1050, pci bus id: 0000:01:00.0, compute capability: 6.1"
# xla_global_id: 416903419
# ]

# %%
filters = 32      # the dimensionality of the output space
kernel_size = 3   # length of the 2D convolution window
max_pool = 2      # size of the max pooling windows

# %%
EPOCHS = 70                                  # while testing you can change it
batch_size = 32                              # number of training samples using in each mini batch during GD (gradient descent) 
iter_per_epoch = len(X_train) // batch_size  # each sample will be passed [iter_per_epoch] times during training
val_per_epoch = len(X_val) // batch_size     # each sample will be passed [val_per_epoch] times during validation

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D,GlobalMaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization
from keras import optimizers
from tensorflow.keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D, Flatten
from tensorflow.keras.layers import BatchNormalization
from keras.layers.core import Dense, Dropout, Activation
from keras.utils import np_utils 
import keras
from keras import optimizers

# %%
model = Sequential()

# first layer
model.add(Conv2D(batch_size, (kernel_size, kernel_size), activation='relu', padding='same', input_shape=(128, 128, 3))) # 32
model.add(MaxPooling2D((max_pool, max_pool))) #reduce the spatial size of incoming features

# second layer
model.add(Conv2D(2*batch_size, (kernel_size, kernel_size), activation='relu', padding='same')) # 64
model.add(MaxPooling2D((max_pool, max_pool))) 

# third layer
model.add(Conv2D(4*batch_size, (kernel_size, kernel_size), activation='relu', padding='same')) # 128
model.add(MaxPooling2D((max_pool, max_pool))) 

# fourth layer
model.add(Conv2D(4*batch_size, (kernel_size, kernel_size), activation='relu', padding='same')) # 128
model.add(AveragePooling2D(pool_size= (2, 2), strides= (2, 2))) 

# fifth layer
model.add(Conv2D(4*batch_size, (kernel_size, kernel_size), activation='relu', padding='same')) # 128
model.add(MaxPooling2D((max_pool, max_pool))) 

model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(16*batch_size, activation='relu'))                                             # 512
model.add(Dense(7, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 128, 128, 32)      896
#
#  max_pooling2d_4 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 128)       147584
#
#  average_pooling2d_1 (Averag  (None, 8, 8, 128)        0
#  ePooling2D)
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_7 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 512)               1049088
#
#  dense_3 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 1,441,095
# Trainable params: 1,441,095
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_train    #sparse
# Out:
# array([2, 3, 4, ..., 3, 4, 2])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(              # this is the augmentation configuration used for training
        zoom_range=0.1,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True
        )

val_datagen = ImageDataGenerator()                # for val/testing only rescaling function

# %%
n = randint(0,len(X_train))
samples = np.expand_dims(X_train[n], 0)
it = train_datagen.flow(samples, batch_size=batch_size)
cols = 7

fig, ax = plt.subplots(nrows=1, ncols=cols, figsize=(15, 10))
ax[0].imshow(X_train[n], cmap='gray')
ax[0].set_title('Original', fontsize=10)

for i in range(1,cols):
    batch = it.next()    # generate batch of images 
    image = batch[0].astype('uint32') # convert to unsigned int for viewing
    ax[i].set_title('augmented {}'.format(i), fontsize=10)
    ax[i].imshow(image, cmap='gray')

# %%
train_gen = train_datagen.flow(X_train, y_train, batch_size=batch_size)
val_gen = val_datagen.flow(X_val, y_val, batch_size=batch_size)

# %%
m = model.fit_generator(
       train_gen,
       steps_per_epoch= iter_per_epoch,
       epochs=EPOCHS, 
       validation_data = val_gen,
       validation_steps = val_per_epoch,
       verbose = 1 # Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch.
       )
# Out:
# Epoch 1/70
# 56/56 [==============================] - 8s 116ms/step - loss: 3.4168 - accuracy: 0.1618 - val_loss: 1.8404 - val_accuracy: 0.2902
# Epoch 2/70
# 56/56 [==============================] - 6s 110ms/step - loss: 1.7406 - accuracy: 0.3092 - val_loss: 1.2964 - val_accuracy: 0.5112
# Epoch 3/70
# 56/56 [==============================] - 6s 108ms/step - loss: 1.3150 - accuracy: 0.4877 - val_loss: 0.8203 - val_accuracy: 0.6763
# Epoch 4/70
# 56/56 [==============================] - 6s 111ms/step - loss: 1.0760 - accuracy: 0.5820 - val_loss: 1.0084 - val_accuracy: 0.6406
# Epoch 5/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.9030 - accuracy: 0.6501 - val_loss: 0.5764 - val_accuracy: 0.8080
# Epoch 6/70
# 56/56 [==============================] - 6s 108ms/step - loss: 0.7301 - accuracy: 0.7338 - val_loss: 0.6572 - val_accuracy: 0.7746
# Epoch 7/70
# 56/56 [==============================] - 6s 111ms/step - loss: 0.6039 - accuracy: 0.7706 - val_loss: 0.3908 - val_accuracy: 0.8638
# Epoch 8/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.5567 - accuracy: 0.7946 - val_loss: 0.2826 - val_accuracy: 0.9196
# Epoch 9/70
# 56/56 [==============================] - 6s 108ms/step - loss: 0.4823 - accuracy: 0.8292 - val_loss: 0.2194 - val_accuracy: 0.9420
# Epoch 10/70
# 56/56 [==============================] - 6s 111ms/step - loss: 0.4276 - accuracy: 0.8315 - val_loss: 0.2602 - val_accuracy: 0.9040
# Epoch 11/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.4093 - accuracy: 0.8527 - val_loss: 0.2665 - val_accuracy: 0.9040
# Epoch 12/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.3626 - accuracy: 0.8689 - val_loss: 0.1821 - val_accuracy: 0.9375
# Epoch 13/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.3301 - accuracy: 0.8806 - val_loss: 0.1580 - val_accuracy: 0.9598
# Epoch 14/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.2838 - accuracy: 0.8945 - val_loss: 0.2434 - val_accuracy: 0.9196
# Epoch 15/70
# 56/56 [==============================] - 6s 111ms/step - loss: 0.2266 - accuracy: 0.9280 - val_loss: 0.1022 - val_accuracy: 0.9710
# Epoch 16/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.1786 - accuracy: 0.9381 - val_loss: 0.0776 - val_accuracy: 0.9732
# Epoch 17/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.1880 - accuracy: 0.9403 - val_loss: 0.2062 - val_accuracy: 0.9330
# Epoch 18/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.1761 - accuracy: 0.9375 - val_loss: 0.1568 - val_accuracy: 0.9487
# Epoch 19/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.1540 - accuracy: 0.9386 - val_loss: 0.0626 - val_accuracy: 0.9799
# Epoch 20/70
# 56/56 [==============================] - 6s 112ms/step - loss: 0.1377 - accuracy: 0.9548 - val_loss: 0.1087 - val_accuracy: 0.9688
# Epoch 21/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.1629 - accuracy: 0.9459 - val_loss: 0.0574 - val_accuracy: 0.9866
# Epoch 22/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.1544 - accuracy: 0.9509 - val_loss: 0.1275 - val_accuracy: 0.9464
# Epoch 23/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.1240 - accuracy: 0.9654 - val_loss: 0.0625 - val_accuracy: 0.9844
# Epoch 24/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.1282 - accuracy: 0.9581 - val_loss: 0.0739 - val_accuracy: 0.9710
# Epoch 25/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0824 - accuracy: 0.9699 - val_loss: 0.0661 - val_accuracy: 0.9821
# Epoch 26/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.1074 - accuracy: 0.9626 - val_loss: 0.0608 - val_accuracy: 0.9866
# Epoch 27/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.1528 - accuracy: 0.9481 - val_loss: 0.0663 - val_accuracy: 0.9777
# Epoch 28/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.1349 - accuracy: 0.9492 - val_loss: 0.1002 - val_accuracy: 0.9621
# Epoch 29/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.1322 - accuracy: 0.9570 - val_loss: 0.0367 - val_accuracy: 0.9911
# Epoch 30/70
# 56/56 [==============================] - 6s 113ms/step - loss: 0.0917 - accuracy: 0.9643 - val_loss: 0.0745 - val_accuracy: 0.9777
# Epoch 31/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.1197 - accuracy: 0.9587 - val_loss: 0.0998 - val_accuracy: 0.9576
# Epoch 32/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.0873 - accuracy: 0.9704 - val_loss: 0.0511 - val_accuracy: 0.9866
# Epoch 33/70
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0969 - accuracy: 0.9654 - val_loss: 0.0844 - val_accuracy: 0.9710
# Epoch 34/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.0677 - accuracy: 0.9777 - val_loss: 0.1093 - val_accuracy: 0.9643
# Epoch 35/70
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0814 - accuracy: 0.9704 - val_loss: 0.0342 - val_accuracy: 0.9911
# Epoch 36/70
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0767 - accuracy: 0.9743 - val_loss: 0.1223 - val_accuracy: 0.9665
# Epoch 37/70
# 56/56 [==============================] - 7s 117ms/step - loss: 0.0954 - accuracy: 0.9693 - val_loss: 0.0498 - val_accuracy: 0.9866
# Epoch 38/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0823 - accuracy: 0.9715 - val_loss: 0.0498 - val_accuracy: 0.9844
# Epoch 39/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0754 - accuracy: 0.9743 - val_loss: 0.0595 - val_accuracy: 0.9799
# Epoch 40/70
# 56/56 [==============================] - 6s 111ms/step - loss: 0.1001 - accuracy: 0.9643 - val_loss: 0.0780 - val_accuracy: 0.9821
# Epoch 41/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0961 - accuracy: 0.9665 - val_loss: 0.0471 - val_accuracy: 0.9821
# Epoch 42/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0737 - accuracy: 0.9754 - val_loss: 0.0555 - val_accuracy: 0.9844
# Epoch 43/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0889 - accuracy: 0.9715 - val_loss: 0.0542 - val_accuracy: 0.9777
# Epoch 44/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0856 - accuracy: 0.9715 - val_loss: 0.0213 - val_accuracy: 0.9933
# Epoch 45/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0626 - accuracy: 0.9810 - val_loss: 0.0696 - val_accuracy: 0.9799
# Epoch 46/70
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0589 - accuracy: 0.9799 - val_loss: 0.0563 - val_accuracy: 0.9888
# Epoch 47/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0478 - accuracy: 0.9821 - val_loss: 0.0314 - val_accuracy: 0.9866
# Epoch 48/70
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0638 - accuracy: 0.9805 - val_loss: 0.0615 - val_accuracy: 0.9777
# Epoch 49/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0510 - accuracy: 0.9849 - val_loss: 0.0354 - val_accuracy: 0.9933
# Epoch 50/70
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0881 - accuracy: 0.9721 - val_loss: 0.0810 - val_accuracy: 0.9799
# Epoch 51/70
# 56/56 [==============================] - 6s 111ms/step - loss: 0.1265 - accuracy: 0.9604 - val_loss: 0.0135 - val_accuracy: 0.9978
# Epoch 52/70
# 56/56 [==============================] - 6s 112ms/step - loss: 0.0534 - accuracy: 0.9805 - val_loss: 0.0127 - val_accuracy: 0.9955
# Epoch 53/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.0916 - accuracy: 0.9715 - val_loss: 0.0709 - val_accuracy: 0.9665
# Epoch 54/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0781 - accuracy: 0.9749 - val_loss: 0.0382 - val_accuracy: 0.9866
# Epoch 55/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0536 - accuracy: 0.9799 - val_loss: 0.0157 - val_accuracy: 0.9933
# Epoch 56/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0304 - accuracy: 0.9894 - val_loss: 0.0310 - val_accuracy: 0.9888
# Epoch 57/70
# 56/56 [==============================] - 6s 114ms/step - loss: 0.0775 - accuracy: 0.9766 - val_loss: 0.0211 - val_accuracy: 0.9888
# Epoch 58/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.0381 - accuracy: 0.9872 - val_loss: 0.0272 - val_accuracy: 0.9933
# Epoch 59/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.0785 - accuracy: 0.9754 - val_loss: 0.0828 - val_accuracy: 0.9799
# Epoch 60/70
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0587 - accuracy: 0.9821 - val_loss: 0.0305 - val_accuracy: 0.9888
# Epoch 61/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.0507 - accuracy: 0.9771 - val_loss: 0.0206 - val_accuracy: 0.9888
# Epoch 62/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.0700 - accuracy: 0.9799 - val_loss: 0.0278 - val_accuracy: 0.9866
# Epoch 63/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.0811 - accuracy: 0.9754 - val_loss: 0.0239 - val_accuracy: 0.9888
# Epoch 64/70
# 56/56 [==============================] - 6s 108ms/step - loss: 0.0277 - accuracy: 0.9877 - val_loss: 0.0281 - val_accuracy: 0.9866
# Epoch 65/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.0535 - accuracy: 0.9833 - val_loss: 0.0130 - val_accuracy: 0.9978
# Epoch 66/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.0524 - accuracy: 0.9838 - val_loss: 0.0164 - val_accuracy: 0.9955
# Epoch 67/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.0704 - accuracy: 0.9760 - val_loss: 0.0393 - val_accuracy: 0.9888
# Epoch 68/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.0682 - accuracy: 0.9766 - val_loss: 0.0241 - val_accuracy: 0.9888
# Epoch 69/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.0636 - accuracy: 0.9777 - val_loss: 0.0227 - val_accuracy: 0.9888
# Epoch 70/70
# 56/56 [==============================] - 6s 109ms/step - loss: 0.0705 - accuracy: 0.9782 - val_loss: 0.0236 - val_accuracy: 0.9911

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
axs[0].plot(m.history['accuracy'])
axs[0].plot(m.history['val_accuracy'])
axs[0].set_title('Model accuracy')
axs[0].legend(['Train', 'Val'], loc='upper left')

axs[1].plot(m.history['loss'])
axs[1].plot(m.history['val_loss'])
axs[1].set_title('Model loss')
axs[1].legend(['Train', 'Val'], loc='upper left')

for ax in axs.flat:
    ax.set(xlabel='Epoch')

# %%
score = model.evaluate_generator(val_gen, steps= len(val_gen))

for idx, metric in enumerate(model.metrics_names):
    print('{}:{}'.format(metric, score[idx]))
# Out:
# loss:0.02363450825214386
# accuracy:0.9910714030265808

# %%
from sklearn.metrics import confusion_matrix
y_pre_test=model.predict(X_val)
y_pre_test=np.argmax(y_pre_test,axis=1)
cm=confusion_matrix(y_val,y_pre_test)

plt.figure(figsize = (15,15))
sn.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
import matplotlib.pyplot as plt     

ax= plt.subplot()
sns.heatmap(cm, annot=True,linecolor='white', cmap='Reds', linewidth=2, fmt='', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(classlist); ax.yaxis.set_ticklabels(classlist);
plt.xticks(rotation=90)
plt.yticks(rotation=0)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5]),
#  [Text(0, 0.5, 'angry'),
#   Text(0, 1.5, 'disgust'),
#   Text(0, 2.5, 'fear'),
#   Text(0, 3.5, 'happy'),
#   Text(0, 4.5, 'neutral'),
#   Text(0, 5.5, 'ps'),
#   Text(0, 6.5, 'sad')])

# %%
x=(y_pre_test-y_val!=0).tolist()
x=[i for i,l in enumerate(x) if l!=False]

fig,ax=plt.subplots(1,4,sharey=False,figsize=(13,13))
fig.tight_layout()

for i in range(4):
    ax[i].imshow(X_val[x[i]][:,:,1])
    ax[i].set_xlabel('{}, Pred: {}'.format(CLASSES[y_val[x[i]]],CLASSES[y_pre_test[x[i]]]))

# %%
model.save('tess_best_2dcnn.h5')

# %%
# cont :
http://localhost:8888/notebooks/thesis_codes/8_CNN_1D_shEMO_TR_LEARNING/ravdess_better/gemstones-multiclass-classification-cnn.ipynb

# %%
# X_train, X_val, y_train, y_val

# %%
#model.save('model_gemstones.h5')
"""
test_dir = '/test/'
Test_Imgs, Test_Lbls = read_imgs_lbls(test_dir)
Test_Lbls = get_class_index(Test_Lbls)



"""
# Out:
# "\ntest_dir = '/test/'\nTest_Imgs, Test_Lbls = read_imgs_lbls(test_dir)\nTest_Lbls = get_class_index(Test_Lbls)\n\n\n\n"

# %%
"""Test_Imgs = crop_images(Test_Imgs)
print('shape of images in test set: {} '.format(Test_Imgs.shape))

"""
# Out:
# "Test_Imgs = crop_images(Test_Imgs)\nprint('shape of images in test set: {} '.format(Test_Imgs.shape))\n\n"

# %%
""" f,ax = plt.subplots(5,5) 
f.subplots_adjust(0,0,2,2)
for i in range(0,5,1):
    for j in range(0,5,1):
        rnd_number = randint(0,len(Test_Imgs))
        pred_image = np.array([Test_Imgs[rnd_number]])
        pred_class = model.predict_classes(pred_image)[0]
        pred_prob = model.predict(pred_image).reshape(87)
        act = CLASSES[Test_Lbls[rnd_number]]
        ax[i,j].imshow(Test_Imgs[rnd_number])
        ax[i,j].imshow(pred_image[0])
        if(CLASSES[pred_class] != CLASSES[Test_Lbls[rnd_number]]):
            t = '{} [{}]'.format(CLASSES[pred_class], CLASSES[Test_Lbls[rnd_number]])
            ax[i,j].set_title(t, fontdict={'color': 'darkred'})
        else:
            t = '[OK] {}'.format(CLASSES[pred_class]) 
            ax[i,j].set_title(t)
        ax[i,j].axis('off')
        
        """
# Out:
# " f,ax = plt.subplots(5,5) \nf.subplots_adjust(0,0,2,2)\nfor i in range(0,5,1):\n    for j in range(0,5,1):\n        rnd_number = randint(0,len(Test_Imgs))\n        pred_image = np.array([Test_Imgs[rnd_number]])\n        pred_class = model.predict_classes(pred_image)[0]\n        pred_prob = model.predict(pred_image).reshape(87)\n        act = CLASSES[Test_Lbls[rnd_number]]\n        ax[i,j].imshow(Test_Imgs[rnd_number])\n        ax[i,j].imshow(pred_image[0])\n        if(CLASSES[pred_class] != CLASSES[Test_Lbls[rnd_number]]):\n            t = '{} [{}]'.format(CLASSES[pred_class], CLASSES[Test_Lbls[rnd_number]])\n            ax[i,j].set_title(t, fontdict={'color': 'darkred'})\n        else:\n            t = '[OK] {}'.format(CLASSES[pred_class]) \n            ax[i,j].set_title(t)\n        ax[i,j].axis('off')\n        \n        "

# %% [markdown]
# ## check spectrogram

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import librosa
import librosa.display 
Ravdess = "D:/AAA_video_course/Programming/dataset/"

# %%
ravdess_directory_list = os.listdir(Ravdess)

file_emotion = []
file_path = []
for dir in ravdess_directory_list:
    # as their are 20 different actors in our previous directory we need to extract files for each actor.
    actor = os.listdir(Ravdess + dir)
    for file in actor:
        part = file.split('.')[0]
        part = part.split('-')
        # third part in each file represents the emotion associated to that file.
        file_emotion.append(int(part[2]))
        file_path.append(Ravdess + dir + '/' + file)
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Ravdess_df = pd.concat([emotion_df, path_df], axis=1)

# changing integers to actual emotions.
Ravdess_df.Emotions.replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}, inplace=True)
Ravdess_df.head()

# %%
import seaborn as sns
plt.title('Count of Emotions', size=16)
sns.countplot(Ravdess_df.Emotions)
plt.ylabel('Count', size=12)
plt.xlabel('Emotions', size=12)
sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
def create_waveplot(data, sr, e):
    plt.figure(figsize=(10, 3))
    plt.title('Waveplot for audio with {} emotion'.format(e), size=15)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
    
def create_spectrogram(data, sr, e):
    # stft function converts the data into short term fourier transform
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(12, 3))
    plt.title('Spectrogram for audio with {} emotion'.format(e), size=15)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')   
    #librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar()

# %%
data_path = Ravdess_df

# %%
from IPython.display import Audio

emotion='fear'
path = np.array(data_path.Path[data_path.Emotions==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)

# %%
emotion='happy'
path = np.array(data_path.Path[data_path.Emotions==emotion])[20]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)

# %%
emotion='angry'
path = np.array(data_path.Path[data_path.Emotions==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)

# %%
p = 'D:/AAA_video_course/Programming/dataset/Actor_18/03-01-07-02-02-02-18.wav'

# %%
data, sampling_rate = librosa.load(p)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
